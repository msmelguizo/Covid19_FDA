# %% [markdown]
# # Import Libraries for analysis

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import OneHotEncoder
from sklearn import metrics

#Light GBM
import lightgbm as lgb


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

PATH = '/media/maria/2TB Monster driv/PrecisionFDA/'

# %% [markdown]
# # Import Databases

# %%
train = pd.read_csv(PATH + 'Descriptive/train.csv')
test = pd.read_csv(PATH + 'Descriptive/test.csv')

# %%
train.shape
# Out:
# (117959, 945)

# %%
#train.pivot_table(CITY, COVID_Status)

# %%
#Display all database


def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %%
display_all(train.describe())
# Out:
#              DRIVERS       PASSPORT            LAT            LON  \
# count  117959.000000  117959.000000  117959.000000  117959.000000
# mean        0.984935       0.981850      42.277738     -71.359432
# std         0.121810       0.133496       0.280501       0.596897
# min         0.000000       0.000000      41.241591     -73.490615
# 25%         1.000000       1.000000      42.127746     -71.547992
# 50%         1.000000       1.000000      42.317212     -71.154750
# 75%         1.000000       1.000000      42.456261     -71.024435
# max         1.000000       1.000000      42.901078     -69.921561
#
#        HEALTHCARE_EXPENSES  HEALTHCARE_COVERAGE            Age  \
# count         1.179590e+05         1.179590e+05  117959.000000
# mean          1.023666e+06         3.471099e+04      55.384600
# std           5.461491e+05         8.334722e+04      18.783242
# min           5.166400e+02         0.000000e+00       0.000000
# 25%           6.093919e+05         5.097815e+03      40.000000
# 50%           1.168081e+06         9.236690e+03      59.000000
# 75%           1.467964e+06         1.819100e+04      71.000000
# max           3.203008e+06         1.557373e+06      84.000000
#
#        Allergy to bee venom  Allergy to dairy product  Allergy to eggs  \
# count          10896.000000              10896.000000     10896.000000
# mean               0.172540                  0.038179         0.049284
# std                0.377867                  0.191637         0.216471
# min                0.000000                  0.000000         0.000000
# 25%                0.000000                  0.000000         0.000000
# 50%                0.000000                  0.000000         0.000000
# 75%                0.000000                  0.000000         0.000000
# max                1.000000                  1.000000         1.000000
#
#        Allergy to fish  Allergy to grass pollen  Allergy to mould  \
# count     10896.000000             10896.000000      10896.000000
# mean          0.167676                 0.254589          0.363803
# std           0.373596                 0.435650          0.481115
# min           0.000000                 0.000000          0.000000
# 25%           0.000000                 0.000000          0.000000
# 50%           0.000000                 0.000000          0.000000
# 75%           0.000000                 1.000000          1.000000
# max           1.000000                 1.000000          1.000000
#
#        Allergy to nut  Allergy to peanuts  Allergy to soya  \
# count    10896.000000        10896.000000     10896.000000
# mean         0.169787            0.188418         0.016887
# std          0.375463            0.391063         0.128854
# min          0.000000            0.000000         0.000000
# 25%          0.000000            0.000000         0.000000
# 50%          0.000000            0.000000         0.000000
# 75%          0.000000            0.000000         0.000000
# max          1.000000            1.000000         1.000000
#
#        Allergy to tree pollen  Allergy to wheat  Dander (animal) allergy  \
# count            10896.000000      10896.000000             10896.000000
# mean                 0.251836          0.045338                 0.334526
# std                  0.434087          0.208053                 0.471846
# min                  0.000000          0.000000                 0.000000
# 25%                  0.000000          0.000000                 0.000000
# 50%                  0.000000          0.000000                 0.000000
# 75%                  1.000000          0.000000                 1.000000
# max                  1.000000          1.000000                 1.000000
#
#        House dust mite allergy  Latex allergy  Shellfish allergy  \
# count             10896.000000   10896.000000        10896.00000
# mean                  0.248807       0.068741            0.32801
# std                   0.432342       0.253024            0.46951
# min                   0.000000       0.000000            0.00000
# 25%                   0.000000       0.000000            0.00000
# 50%                   0.000000       0.000000            0.00000
# 75%                   0.000000       0.000000            1.00000
# max                   1.000000       1.000000            1.00000
#
#        Agreeing on diabetes care plan  Allergic disorder monitoring  \
# count                   108045.000000                 108045.000000
# mean                         0.000305                      0.001897
# std                          0.017474                      0.043518
# min                          0.000000                      0.000000
# 25%                          0.000000                      0.000000
# 50%                          0.000000                      0.000000
# 75%                          0.000000                      0.000000
# max                          1.000000                      1.000000
#
#        Anti-suicide psychotherapy  Asthma self management      Burn care  \
# count               108045.000000           108045.000000  108045.000000
# mean                     0.002379                0.039567       0.003267
# std                      0.048713                0.194940       0.057389
# min                      0.000000                0.000000       0.000000
# 25%                      0.000000                0.000000       0.000000
# 50%                      0.000000                0.000000       0.000000
# 75%                      0.000000                0.000000       0.000000
# max                      1.000000                1.000000       2.000000
#
#        Cancer care plan      Care Plan  Care plan (record artifact)  \
# count     108045.000000  108045.000000                108045.000000
# mean           0.202740       0.337609                     0.049081
# std            0.410471       0.472897                     0.216039
# min            0.000000       0.000000                     0.000000
# 25%            0.000000       0.000000                     0.000000
# 50%            0.000000       0.000000                     0.000000
# 75%            0.000000       1.000000                     0.000000
# max            2.000000       1.000000                     1.000000
#
#        Chronic obstructive pulmonary disease clinical management plan  \
# count                                      108045.000000
# mean                                            0.048869
# std                                             0.215594
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Demential management  Diabetes self management plan  \
# count         108045.000000                  108045.000000
# mean               0.050766                       0.609940
# std                0.219520                       0.487766
# min                0.000000                       0.000000
# 25%                0.000000                       0.000000
# 50%                0.000000                       1.000000
# 75%                0.000000                       1.000000
# max                1.000000                       1.000000
#
#        Dialysis care plan (record artifact)  Fracture care  \
# count                         108045.000000  108045.000000
# mean                               0.012680       0.022685
# std                                0.111889       0.169207
# min                                0.000000       0.000000
# 25%                                0.000000       0.000000
# 50%                                0.000000       0.000000
# 75%                                0.000000       0.000000
# max                                1.000000       7.000000
#
#        Head injury rehabilitation  Heart failure self management plan  \
# count               108045.000000                       108045.000000
# mean                     0.006840                            0.072498
# std                      0.086046                            0.259311
# min                      0.000000                            0.000000
# 25%                      0.000000                            0.000000
# 50%                      0.000000                            0.000000
# 75%                      0.000000                            0.000000
# max                      4.000000                            1.000000
#
#        Hyperlipidemia clinical management plan  \
# count                            108045.000000
# mean                                  0.196511
# std                                   0.397361
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000
#
#        Inpatient care plan (record artifact)  \
# count                          108045.000000
# mean                                0.075561
# std                                 0.313239
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 6.000000
#
#        Lifestyle education regarding hypertension  \
# count                               108045.000000
# mean                                     0.391180
# std                                      0.488017
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      1.000000
# max                                      1.000000
#
#        Major depressive disorder clinical management plan  \
# count                                      108045.000000
# mean                                            0.066981
# std                                             0.249991
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Major surgery care management  Mental health care plan  \
# count                  108045.000000            108045.000000
# mean                        0.002027                 0.147179
# std                         0.044976                 0.354286
# min                         0.000000                 0.000000
# 25%                         0.000000                 0.000000
# 50%                         0.000000                 0.000000
# 75%                         0.000000                 0.000000
# max                         1.000000                 1.000000
#
#        Mental health care plan (record artifact)  \
# count                              108045.000000
# mean                                    0.002647
# std                                     0.051382
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Minor surgery care management (procedure)  Musculoskeletal care  \
# count                              108045.000000         108045.000000
# mean                                    0.001805              0.190985
# std                                     0.042445              0.484899
# min                                     0.000000              0.000000
# 25%                                     0.000000              0.000000
# 50%                                     0.000000              0.000000
# 75%                                     0.000000              0.000000
# max                                     1.000000              6.000000
#
#        Overactivity/inattention behavior management  \
# count                                 108045.000000
# mean                                       0.000435
# std                                        0.020852
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        Physical therapy procedure  Postoperative care  Psychiatry care plan  \
# count               108045.000000       108045.000000         108045.000000
# mean                     0.016863            0.000379              0.196178
# std                      0.142022            0.019476              0.397106
# min                      0.000000            0.000000              0.000000
# 25%                      0.000000            0.000000              0.000000
# 50%                      0.000000            0.000000              0.000000
# 75%                      0.000000            0.000000              0.000000
# max                      5.000000            1.000000              1.000000
#
#        Respiratory therapy  Routine antenatal care  \
# count        108045.000000           108045.000000
# mean              0.126012                0.125698
# std               0.603319                0.715589
# min               0.000000                0.000000
# 25%               0.000000                0.000000
# 50%               0.000000                0.000000
# 75%               0.000000                0.000000
# max              11.000000               11.000000
#
#        Self-care interventions (procedure)  Skin condition care  \
# count                        108045.000000        108045.000000
# mean                              0.157101             0.006238
# std                               0.363898             0.078736
# min                               0.000000             0.000000
# 25%                               0.000000             0.000000
# 50%                               0.000000             0.000000
# 75%                               0.000000             0.000000
# max                               1.000000             1.000000
#
#        Spinal cord injury rehabilitation  Terminal care  \
# count                      108045.000000  108045.000000
# mean                            0.000120       0.087066
# std                             0.010968       0.281932
# min                             0.000000       0.000000
# 25%                             0.000000       0.000000
# 50%                             0.000000       0.000000
# 75%                             0.000000       0.000000
# max                             1.000000       1.000000
#
#        Urinary tract infection care     Wound care  \
# count                 108045.000000  108045.000000
# mean                       0.003230       0.012967
# std                        0.057873       0.116914
# min                        0.000000       0.000000
# 25%                        0.000000       0.000000
# 50%                        0.000000       0.000000
# 75%                        0.000000       0.000000
# max                        2.000000       4.000000
#
#        Acute bronchitis (disorder)_x  Alzheimer's disease (disorder)_x  \
# count                  105179.000000                      105179.00000
# mean                        0.129446                           0.04093
# std                         0.611120                           0.19813
# min                         0.000000                           0.00000
# 25%                         0.000000                           0.00000
# 50%                         0.000000                           0.00000
# 75%                         0.000000                           0.00000
# max                        11.000000                           1.00000
#
#             Asthma_x  At risk for suicide (finding)_x  Atopic dermatitis_x  \
# count  105179.000000                    105179.000000        105179.000000
# mean        0.002168                         0.000171             0.005590
# std         0.046509                         0.015722             0.074561
# min         0.000000                         0.000000             0.000000
# 25%         0.000000                         0.000000             0.000000
# 50%         0.000000                         0.000000             0.000000
# 75%         0.000000                         0.000000             0.000000
# max         1.000000                         2.000000             1.000000
#
#        Attempted suicide - cut/stab_x  Attempted suicide - suffocation_x  \
# count                   105179.000000                      105179.000000
# mean                         0.000456                           0.000333
# std                          0.021358                           0.018239
# min                          0.000000                           0.000000
# 25%                          0.000000                           0.000000
# 50%                          0.000000                           0.000000
# 75%                          0.000000                           0.000000
# max                          1.000000                           1.000000
#
#        Bullet wound_x  Child attention deficit disorder_x  Childhood asthma_x  \
# count   105179.000000                       105179.000000       105179.000000
# mean         0.000219                            0.000447            0.038477
# std          0.014786                            0.021134            0.192346
# min          0.000000                            0.000000            0.000000
# 25%          0.000000                            0.000000            0.000000
# 50%          0.000000                            0.000000            0.000000
# 75%          0.000000                            0.000000            0.000000
# max          1.000000                            1.000000            1.000000
#
#        Chronic congestive heart failure (disorder)_x  \
# count                                  105179.000000
# mean                                        0.074473
# std                                         0.262540
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        Chronic obstructive bronchitis (disorder)_x  Closed fracture of hip_x  \
# count                                105179.000000             105179.000000
# mean                                      0.023284                  0.001959
# std                                       0.150805                  0.044427
# min                                       0.000000                  0.000000
# 25%                                       0.000000                  0.000000
# 50%                                       0.000000                  0.000000
# 75%                                       0.000000                  0.000000
# max                                       1.000000                  2.000000
#
#        Concussion injury of brain_x  Concussion with loss of consciousness_x  \
# count                 105179.000000                            105179.000000
# mean                       0.000371                                 0.001369
# std                        0.019253                                 0.036976
# min                        0.000000                                 0.000000
# 25%                        0.000000                                 0.000000
# 50%                        0.000000                                 0.000000
# 75%                        0.000000                                 0.000000
# max                        1.000000                                 1.000000
#
#        Concussion with no loss of consciousness_x  Contact dermatitis_x  \
# count                               105179.000000         105179.000000
# mean                                     0.005286              0.000818
# std                                      0.075847              0.028583
# min                                      0.000000              0.000000
# 25%                                      0.000000              0.000000
# 50%                                      0.000000              0.000000
# 75%                                      0.000000              0.000000
# max                                      4.000000              1.000000
#
#        Cystic Fibrosis_x     Cystitis_x     Diabetes_x  \
# count      105179.000000  105179.000000  105179.000000
# mean            0.000361       0.001312       0.158473
# std             0.019004       0.036460       0.365185
# min             0.000000       0.000000       0.000000
# 25%             0.000000       0.000000       0.000000
# 50%             0.000000       0.000000       0.000000
# 75%             0.000000       0.000000       0.000000
# max             1.000000       2.000000       1.000000
#
#        Diabetes from Cystic Fibrosis_x  Drug overdose_x  \
# count                    105179.000000     105179.00000
# mean                          0.000143          0.05889
# std                           0.011941          0.23542
# min                           0.000000          0.00000
# 25%                           0.000000          0.00000
# 50%                           0.000000          0.00000
# 75%                           0.000000          0.00000
# max                           1.000000          1.00000
#
#        Escherichia coli urinary tract infection_x  Facial laceration_x  \
# count                               105179.000000        105179.000000
# mean                                     0.001968             0.002577
# std                                      0.044747             0.051808
# min                                      0.000000             0.000000
# 25%                                      0.000000             0.000000
# 50%                                      0.000000             0.000000
# 75%                                      0.000000             0.000000
# max                                      2.000000             3.000000
#
#        Familial Alzheimer's disease of early onset (disorder)_x  \
# count                                      105179.000000
# mean                                            0.011219
# std                                             0.105324
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        First degree burn_x  Fracture of ankle_x  Fracture of clavicle_x  \
# count        105179.000000        105179.000000           105179.000000
# mean              0.001873             0.004421                0.004716
# std               0.043457             0.069013                0.070426
# min               0.000000             0.000000                0.000000
# 25%               0.000000             0.000000                0.000000
# 50%               0.000000             0.000000                0.000000
# 75%               0.000000             0.000000                0.000000
# max               2.000000             3.000000                2.000000
#
#        Fracture of forearm_x  Fracture of rib_x  \
# count          105179.000000      105179.000000
# mean                0.005838           0.002082
# std                 0.078275           0.045792
# min                 0.000000           0.000000
# 25%                 0.000000           0.000000
# 50%                 0.000000           0.000000
# 75%                 0.000000           0.000000
# max                 2.000000           2.000000
#
#        Fracture of vertebral column without spinal cord injury_x  \
# count                                      105179.000000
# mean                                            0.000124
# std                                             0.011117
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Fracture subluxation of wrist_x         Gout_x  Hyperlipidemia_x  \
# count                    105179.000000  105179.000000     105179.000000
# mean                          0.004288       0.010801          0.201865
# std                           0.067348       0.103364          0.401394
# min                           0.000000       0.000000          0.000000
# 25%                           0.000000       0.000000          0.000000
# 50%                           0.000000       0.000000          0.000000
# 75%                           0.000000       0.000000          0.000000
# max                           2.000000       1.000000          1.000000
#
#        Hypertension_x  Injury of anterior cruciate ligament_x  \
# count   105179.000000                           105179.000000
# mean         0.401839                                0.000608
# std          0.490272                                0.024660
# min          0.000000                                0.000000
# 25%          0.000000                                0.000000
# 50%          0.000000                                0.000000
# 75%          1.000000                                0.000000
# max          1.000000                                1.000000
#
#        Injury of medial collateral ligament of knee_x  \
# count                                   105179.000000
# mean                                         0.000675
# std                                          0.025973
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          1.000000
#
#        Injury of tendon of the rotator cuff of shoulder_x  \
# count                                      105179.000000
# mean                                            0.001626
# std                                             0.040524
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             2.000000
#
#        Laceration of foot_x  Laceration of forearm_x  Laceration of hand_x  \
# count         105179.000000            105179.000000          105179.00000
# mean               0.002472                 0.002757               0.00271
# std                0.050229                 0.052618               0.05253
# min                0.000000                 0.000000               0.00000
# 25%                0.000000                 0.000000               0.00000
# 50%                0.000000                 0.000000               0.00000
# 75%                0.000000                 0.000000               0.00000
# max                2.000000                 2.000000               2.00000
#
#        Laceration of thigh_x  Localized  primary osteoarthritis of the hand_x  \
# count          105179.000000                                    105179.000000
# mean                0.002586                                         0.031831
# std                 0.051161                                         0.175552
# min                 0.000000                                         0.000000
# 25%                 0.000000                                         0.000000
# 50%                 0.000000                                         0.000000
# 75%                 0.000000                                         0.000000
# max                 2.000000                                         1.000000
#
#        Lupus erythematosus_x  Major depression  single episode_x  \
# count          105179.000000                       105179.000000
# mean                0.000114                            0.151190
# std                 0.010681                            0.358236
# min                 0.000000                            0.000000
# 25%                 0.000000                            0.000000
# 50%                 0.000000                            0.000000
# 75%                 0.000000                            0.000000
# max                 1.000000                            1.000000
#
#        Major depression disorder_x  Male Infertility_x  \
# count                105179.000000       105179.000000
# mean                      0.172725            0.000171
# std                       0.475223            0.013081
# min                       0.000000            0.000000
# 25%                       0.000000            0.000000
# 50%                       0.000000            0.000000
# 75%                       0.000000            0.000000
# max                       2.000000            1.000000
#
#        Malignant tumor of colon_x  Neoplasm of prostate_x  \
# count               105179.000000           105179.000000
# mean                     0.009603                0.187062
# std                      0.105574                0.389963
# min                      0.000000                0.000000
# 25%                      0.000000                0.000000
# 50%                      0.000000                0.000000
# 75%                      0.000000                0.000000
# max                      2.000000                1.000000
#
#        Non-small cell carcinoma of lung  TNM stage 1 (disorder)_x  \
# count                                      105179.000000
# mean                                            0.076308
# std                                             0.265492
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Normal pregnancy_x  Osteoarthritis of hip_x  Osteoarthritis of knee_x  \
# count       105179.000000            105179.000000             105179.000000
# mean             0.129123                 0.028209                  0.077230
# std              0.724969                 0.165570                  0.266958
# min              0.000000                 0.000000                  0.000000
# 25%              0.000000                 0.000000                  0.000000
# 50%              0.000000                 0.000000                  0.000000
# 75%              0.000000                 0.000000                  0.000000
# max             11.000000                 1.000000                  1.000000
#
#        Overlapping malignant neoplasm of colon_x  \
# count                              105179.000000
# mean                                    0.008500
# std                                     0.102378
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     2.000000
#
#        Posttraumatic stress disorder_x  Prediabetes_x  \
# count                    105179.000000  105179.000000
# mean                          0.100324       0.468088
# std                           0.309352       0.498983
# min                           0.000000       0.000000
# 25%                           0.000000       0.000000
# 50%                           0.000000       0.000000
# 75%                           0.000000       1.000000
# max                           2.000000       1.000000
#
#        Primary fibromyalgia syndrome_x  Primary malignant neoplasm of colon_x  \
# count                     105179.00000                          105179.000000
# mean                           0.00424                               0.002044
# std                            0.06498                               0.048220
# min                            0.00000                               0.000000
# 25%                            0.00000                               0.000000
# 50%                            0.00000                               0.000000
# 75%                            0.00000                               0.000000
# max                            1.00000                               2.000000
#
#        Primary small cell malignant neoplasm of lung  TNM stage 1 (disorder)_x  \
# count                                      105179.000000
# mean                                            0.013130
# std                                             0.113832
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Pulmonary emphysema (disorder)_x  Pyelonephritis_x  \
# count                     105179.000000     105179.000000
# mean                           0.026916          0.000038
# std                            0.161839          0.006167
# min                            0.000000          0.000000
# 25%                            0.000000          0.000000
# 50%                            0.000000          0.000000
# 75%                            0.000000          0.000000
# max                            1.000000          1.000000
#
#        Rheumatoid arthritis_x  Rupture of patellar tendon_x  \
# count           105179.000000                 105179.000000
# mean                 0.003290                      0.000780
# std                  0.057261                      0.027911
# min                  0.000000                      0.000000
# 25%                  0.000000                      0.000000
# 50%                  0.000000                      0.000000
# 75%                  0.000000                      0.000000
# max                  1.000000                      1.000000
#
#        Second degree burn_x  Secondary malignant neoplasm of colon_x  \
# count         105179.000000                            105179.000000
# mean               0.001312                                 0.003042
# std                0.036199                                 0.055075
# min                0.000000                                 0.000000
# 25%                0.000000                                 0.000000
# 50%                0.000000                                 0.000000
# 75%                0.000000                                 0.000000
# max                1.000000                                 1.000000
#
#        Smokes tobacco daily_x  Sprain of ankle_x  Sprain of wrist_x  \
# count           105179.000000      105179.000000      105179.000000
# mean                 0.164120           0.009051           0.004107
# std                  0.370386           0.099122           0.065572
# min                  0.000000           0.000000           0.000000
# 25%                  0.000000           0.000000           0.000000
# 50%                  0.000000           0.000000           0.000000
# 75%                  0.000000           0.000000           0.000000
# max                  1.000000           4.000000           3.000000
#
#        Suicidal deliberate poisoning_x  Tear of meniscus of knee_x  \
# count                    105179.000000               105179.000000
# mean                          0.001654                    0.000475
# std                           0.040640                    0.021798
# min                           0.000000                    0.000000
# 25%                           0.000000                    0.000000
# 50%                           0.000000                    0.000000
# 75%                           0.000000                    0.000000
# max                           1.000000                    1.000000
#
#        Third degree burn_x  Whiplash injury to neck_x  Acute Cholecystitis_x  \
# count        105179.000000              105179.000000          114521.000000
# mean              0.000171                   0.040474               0.000323
# std               0.013081                   0.219439               0.017972
# min               0.000000                   0.000000               0.000000
# 25%               0.000000                   0.000000               0.000000
# 50%               0.000000                   0.000000               0.000000
# 75%               0.000000                   0.000000               0.000000
# max               1.000000                   5.000000               1.000000
#
#        Acute allergic reaction  Acute bacterial sinusitis (disorder)_x  \
# count            114521.000000                           114521.000000
# mean                  0.000253                                0.005981
# std                   0.015911                                0.080434
# min                   0.000000                                0.000000
# 25%                   0.000000                                0.000000
# 50%                   0.000000                                0.000000
# 75%                   0.000000                                0.000000
# max                   1.000000                                3.000000
#
#        Acute bronchitis (disorder)_y  Acute viral pharyngitis (disorder)_x  \
# count                  114521.000000                         114521.000000
# mean                        0.041669                              0.051205
# std                         0.235720                              0.279053
# min                         0.000000                              0.000000
# 25%                         0.000000                              0.000000
# 50%                         0.000000                              0.000000
# 75%                         0.000000                              0.000000
# max                        10.000000                             11.000000
#
#           Alcoholism  Alzheimer's disease (disorder)_y  Anemia (disorder)_x  \
# count  114521.000000                     114521.000000        114521.000000
# mean        0.120519                          0.037591             0.472891
# std         0.325569                          0.190207             0.499267
# min         0.000000                          0.000000             0.000000
# 25%         0.000000                          0.000000             0.000000
# 50%         0.000000                          0.000000             0.000000
# 75%         0.000000                          0.000000             1.000000
# max         1.000000                          1.000000             1.000000
#
#        Antepartum eclampsia  Appendicitis_x       Asthma_y  \
# count         114521.000000   114521.000000  114521.000000
# mean               0.001327        0.060688       0.001991
# std                0.037120        0.238757       0.044575
# min                0.000000        0.000000       0.000000
# 25%                0.000000        0.000000       0.000000
# 50%                0.000000        0.000000       0.000000
# 75%                0.000000        0.000000       0.000000
# max                3.000000        1.000000       1.000000
#
#        At risk for suicide (finding)_y  Atopic dermatitis_y  \
# count                    114521.000000        114521.000000
# mean                          0.001781             0.005134
# std                           0.042168             0.071471
# min                           0.000000             0.000000
# 25%                           0.000000             0.000000
# 50%                           0.000000             0.000000
# 75%                           0.000000             0.000000
# max                           1.000000             1.000000
#
#        Atrial Fibrillation_x  Bleeding from anus_x  Blighted ovum_x  \
# count          114521.000000         114521.000000    114521.000000
# mean                0.052986              0.006121         0.001022
# std                 0.224006              0.077998         0.032219
# min                 0.000000              0.000000         0.000000
# 25%                 0.000000              0.000000         0.000000
# 50%                 0.000000              0.000000         0.000000
# 75%                 0.000000              0.000000         0.000000
# max                 1.000000              1.000000         2.000000
#
#        Blindness due to type 2 diabetes mellitus (disorder)  \
# count                                      114521.000000
# mean                                            0.000105
# std                                             0.010236
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Body mass index 30+ - obesity (finding)  \
# count                            114521.000000
# mean                                  0.486854
# std                                   0.499829
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   1.000000
# max                                   1.000000
#
#        Body mass index 40+ - severely obese (finding)  \
# count                                   114521.000000
# mean                                         0.011439
# std                                          0.106340
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          1.000000
#
#        Brain damage - traumatic  Bullet wound_y  \
# count             114521.000000   114521.000000
# mean                   0.007780        0.005711
# std                    0.087862        0.075701
# min                    0.000000        0.000000
# 25%                    0.000000        0.000000
# 50%                    0.000000        0.000000
# 75%                    0.000000        0.000000
# max                    1.000000        2.000000
#
#        Burn injury(morphologic abnormality)_x  \
# count                           114521.000000
# mean                                 0.001153
# std                                  0.033931
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        Carcinoma in situ of prostate (disorder)  Cardiac Arrest_x  \
# count                             114521.000000     114521.000000
# mean                                   0.156600          0.049973
# std                                    0.363425          0.217891
# min                                    0.000000          0.000000
# 25%                                    0.000000          0.000000
# 50%                                    0.000000          0.000000
# 75%                                    0.000000          0.000000
# max                                    1.000000          1.000000
#
#        Child attention deficit disorder_y  Childhood asthma_y  Cholelithiasis  \
# count                       114521.000000       114521.000000   114521.000000
# mean                             0.000410            0.000603        0.000323
# std                              0.020254            0.024539        0.017972
# min                              0.000000            0.000000        0.000000
# 25%                              0.000000            0.000000        0.000000
# 50%                              0.000000            0.000000        0.000000
# 75%                              0.000000            0.000000        0.000000
# max                              1.000000            1.000000        1.000000
#
#        Chronic congestive heart failure (disorder)_y  \
# count                                  114521.000000
# mean                                        0.068704
# std                                         0.252950
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        Chronic intractable migraine without aura_x  \
# count                                114521.000000
# mean                                      0.058400
# std                                       0.234499
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                       1.000000
#
#        Chronic kidney disease stage 1 (disorder)  \
# count                              114521.000000
# mean                                    0.158111
# std                                     0.364846
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Chronic kidney disease stage 2 (disorder)  \
# count                              114521.000000
# mean                                    0.024572
# std                                     0.154817
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Chronic kidney disease stage 3 (disorder)  \
# count                              114521.000000
# mean                                    0.001135
# std                                     0.033673
# ...
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     3.000000
#
#        Acute bronchitis (disorder)_y.1  Acute viral pharyngitis (disorder)  \
# count                     35134.000000                        35134.000000
# mean                          0.088148                            0.026214
# std                           0.286013                            0.160307
# min                           0.000000                            0.000000
# 25%                           0.000000                            0.000000
# 50%                           0.000000                            0.000000
# 75%                           0.000000                            0.000000
# max                           2.000000                            2.000000
#
#        Appendicitis  Atrial Fibrillation_y  Bullet wound_y.1  \
# count  35134.000000           35134.000000      35134.000000
# mean       0.001736               0.740565          0.000370
# std        0.041632               3.469013          0.019232
# min        0.000000               0.000000          0.000000
# 25%        0.000000               0.000000          0.000000
# 50%        0.000000               0.000000          0.000000
# 75%        0.000000               0.000000          0.000000
# max        1.000000              51.000000          1.000000
#
#        Cardiac Arrest_y.1  Child attention deficit disorder_y.1  \
# count        35134.000000                          35134.000000
# mean             0.073348                              0.002419
# std              0.463877                              0.159411
# min              0.000000                              0.000000
# 25%              0.000000                              0.000000
# 50%              0.000000                              0.000000
# 75%              0.000000                              0.000000
# max              6.000000                             13.000000
#
#        Chronic obstructive bronchitis (disorder)_y.1  \
# count                                   35134.000000
# mean                                        0.204503
# std                                         1.314446
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                        26.000000
#
#        Closed fracture of hip_y.1  Facial laceration  Fracture of ankle_y.1  \
# count                35134.000000       35134.000000           35134.000000
# mean                     0.006091           0.008026               0.015996
# std                      0.096431           0.101750               0.171639
# min                      0.000000           0.000000               0.000000
# 25%                      0.000000           0.000000               0.000000
# 50%                      0.000000           0.000000               0.000000
# 75%                      0.000000           0.000000               0.000000
# max                      2.000000           2.000000               2.000000
#
#        Fracture of clavicle_y.1  Fracture of forearm_y.1  Fracture of rib_y.1  \
# count              35134.000000             35134.000000         35134.000000
# mean                   0.017106                 0.018728             0.008055
# std                    0.177324                 0.177401             0.123369
# min                    0.000000                 0.000000             0.000000
# 25%                    0.000000                 0.000000             0.000000
# 50%                    0.000000                 0.000000             0.000000
# 75%                    0.000000                 0.000000             0.000000
# max                    2.000000                 2.000000             2.000000
#
#        Fracture subluxation of wrist_y.1  \
# count                       35134.000000
# mean                            0.015512
# std                             0.169598
# min                             0.000000
# 25%                             0.000000
# 50%                             0.000000
# 75%                             0.000000
# max                             2.000000
#
#        Injury of anterior cruciate ligament_y.1  \
# count                              35134.000000
# mean                                   0.001195
# std                                    0.034555
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.000000
# max                                    1.000000
#
#        Injury of medial collateral ligament of knee_y.1  \
# count                                      35134.000000
# mean                                           0.001423
# std                                            0.037698
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# max                                            1.000000
#
#        Injury of tendon of the rotator cuff of shoulder_y.1  \
# count                                       35134.000000
# mean                                            0.000541
# std                                             0.023249
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Laceration of foot  Laceration of forearm  Laceration of hand  \
# count        35134.000000           35134.000000        35134.000000
# mean             0.007827               0.008994            0.008823
# std              0.101064               0.108705            0.108457
# min              0.000000               0.000000            0.000000
# 25%              0.000000               0.000000            0.000000
# 50%              0.000000               0.000000            0.000000
# 75%              0.000000               0.000000            0.000000
# max              2.000000               2.000000            2.000000
#
#        Laceration of thigh  Major depression  single episode_y.1  \
# count          35134.00000                          35134.000000
# mean               0.00851                              0.000199
# std                0.10596                              0.014114
# min                0.00000                              0.000000
# 25%                0.00000                              0.000000
# 50%                0.00000                              0.000000
# 75%                0.00000                              0.000000
# max                2.00000                              1.000000
#
#        Malignant neoplasm of breast (disorder)  Malignant tumor of colon_y.1  \
# count                             35134.000000                  35134.000000
# mean                                  0.275033                      0.016337
# std                                   1.996392                      0.293800
# min                                   0.000000                      0.000000
# 25%                                   0.000000                      0.000000
# 50%                                   0.000000                      0.000000
# 75%                                   0.000000                      0.000000
# max                                  45.000000                      7.000000
#
#        Myocardial Infarction_y.1  Neoplasm of prostate_y.1  \
# count               35134.000000              35134.000000
# mean                    0.275204                  0.021802
# std                     0.870391                  0.146039
# min                     0.000000                  0.000000
# 25%                     0.000000                  0.000000
# 50%                     0.000000                  0.000000
# 75%                     0.000000                  0.000000
# max                     6.000000                  1.000000
#
#        Non-small cell carcinoma of lung  TNM stage 1 (disorder)_y.1  \
# count                                       35134.000000
# mean                                            2.443900
# std                                             4.598634
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            26.000000
#
#        Normal pregnancy_y.1  Overlapping malignant neoplasm of colon_y.1  \
# count          35134.000000                                 35134.000000
# mean               2.215461                                     0.008112
# std                7.435677                                     0.177963
# min                0.000000                                     0.000000
# 25%                0.000000                                     0.000000
# 50%                0.000000                                     0.000000
# 75%                0.000000                                     0.000000
# max               51.000000                                     7.000000
#
#        Polyp of colon  Posttraumatic stress disorder_y.1  \
# count    35134.000000                       35134.000000
# mean         0.060710                           0.014943
# std          0.357392                           0.237825
# min          0.000000                           0.000000
# 25%          0.000000                           0.000000
# 50%          0.000000                           0.000000
# 75%          0.000000                           0.000000
# max          3.000000                           5.000000
#
#        Primary malignant neoplasm of colon_y.1  \
# count                             35134.000000
# mean                                  0.000398
# std                                   0.019958
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000
#
#        Primary small cell malignant neoplasm of lung  TNM stage 1 (disorder)_y.1  \
# count                                       35134.000000
# mean                                            0.540502
# std                                             2.724945
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            27.000000
#
#        Pulmonary emphysema (disorder)_y.1  Recurrent rectal polyp_y  \
# count                        35134.000000              35134.000000
# mean                             0.250697                  0.006319
# std                              1.500992                  0.079240
# min                              0.000000                  0.000000
# 25%                              0.000000                  0.000000
# 50%                              0.000000                  0.000000
# 75%                              0.000000                  0.000000
# max                             26.000000                  1.000000
#
#        Rupture of patellar tendon_y.1  \
# count                    35134.000000
# mean                         0.001651
# std                          0.040597
# min                          0.000000
# 25%                          0.000000
# 50%                          0.000000
# 75%                          0.000000
# max                          1.000000
#
#        Secondary malignant neoplasm of colon_y.1  \
# count                               35134.000000
# mean                                    0.001309
# std                                     0.077669
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     6.000000
#
#        Streptococcal sore throat (disorder)    Stroke_y.1  \
# count                          35134.000000  35134.000000
# mean                               0.018757      0.099106
# std                                0.136295      0.436661
# min                                0.000000      0.000000
# 25%                                0.000000      0.000000
# 50%                                0.000000      0.000000
# 75%                                0.000000      0.000000
# max                                2.000000      4.000000
#
#        Suicidal deliberate poisoning_y.1  Suspected lung cancer (situation)  \
# count                       35134.000000                       35134.000000
# mean                            0.000427                           0.043548
# std                             0.035786                           0.355950
# min                             0.000000                           0.000000
# 25%                             0.000000                           0.000000
# 50%                             0.000000                           0.000000
# 75%                             0.000000                           0.000000
# max                             3.000000                           3.000000
#
#        Third degree burn_y.1  Tubal pregnancy   COVID_Status          Death  \
# count           35134.000000     35134.000000  117959.000000  117959.000000
# mean                0.000911         0.000085       0.624768       0.047203
# std                 0.041999         0.009240       0.484185       0.212073
# min                 0.000000         0.000000       0.000000       0.000000
# 25%                 0.000000         0.000000       0.000000       0.000000
# 50%                 0.000000         0.000000       1.000000       0.000000
# 75%                 0.000000         0.000000       1.000000       0.000000
# max                 2.000000         1.000000       1.000000       1.000000
#
#        Days_hospitalized   Hospitalized     Ventilator     Days_ICU  \
# count       20402.000000  117959.000000  117959.000000  4981.000000
# mean           12.620285       0.172958       0.035690     6.218474
# std             4.946833       0.378213       0.185518     2.757986
# min             1.000000       0.000000       0.000000     1.000000
# 25%             8.252257       0.000000       0.000000     4.063194
# 50%            13.296181       0.000000       0.000000     6.072917
# 75%            16.329167       0.000000       0.000000     8.265278
# max            21.498611       1.000000       1.000000    11.700000
#
#                  ICU
# count  117959.000000
# mean        0.042227
# std         0.201106
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
#save oof
oof_df = train[["Id", "COVID_Status"]]

# %% [markdown]
# # Hyperparameters

# %%
seed = 42
#Using the parameters from ICU mortality 

param = {
            'learning_rate': 0.1, 
            'seed': 50,
            'objective':'binary',
            'boosting_type':'gbdt',
            'metric': 'auc',
        }

# %%
train.drop(columns=['Death', 'Hospitalized', 'Ventilator', 'ICU', 
                    'Id', 'Days_hospitalized', 'Days_ICU', 'COVID_Status'], inplace=True)

# %%
test.drop(columns=['Id'], inplace=True)

# %%
predictors_int = list(train.columns)

# %%
cat_names = ['DRIVERS' , 'PASSPORT', 'MARITAL', 'RACE', 'ETHNICITY',
             'GENDER', 'COUNTY', 'PLACE_BIRTH']

# %%
predictors_int.remove('DRIVERS')
predictors_int.remove('PASSPORT')
predictors_int.remove('MARITAL')
predictors_int.remove('RACE')
predictors_int.remove('ETHNICITY')
predictors_int.remove('GENDER')
predictors_int.remove('COUNTY')
predictors_int.remove('PLACE_BIRTH')

# %% [markdown]
# # Creation of Dummies and missing values handling

# %%
train['is_train'] = 1
test['is_train'] = 0
train_test= pd.concat([train,test], axis = 0, sort=False)
#train_test

# %%
print(train.shape)
test.shape
# Out:
# (117959, 938)
# (29492, 938)

# %%
#one-hot encoding of categorical variables
train_test = pd.get_dummies(train_test, columns = cat_names, dummy_na=True)

# %%
predictors = list(train_test.columns)
#predictors.remove('encounter_id')
predictors.remove('is_train')

# %% [raw]
# predictors.remove('Encounter for symptom (procedure)')
# predictors.remove('Acute respiratory failure (disorder)_x')
# predictors.remove('Oxygen saturation in Arterial blood')
# predictors.remove('Body temperature')
# predictors.remove('Respiratory rate')
# predictors.remove('Heart rate')
# #train.drop(columns=[, ], inplace=True)

# %% [markdown]
# # Training Loop

# %%
train_test.describe()
# Out:
#                  LAT            LON  HEALTHCARE_EXPENSES  HEALTHCARE_COVERAGE  \
# count  147451.000000  147451.000000         1.474510e+05         1.474510e+05
# mean       42.277843     -71.359709         1.024125e+06         3.481290e+04
# std         0.280354       0.597387         5.462107e+05         8.415728e+04
# min        41.241591     -73.490615         5.166400e+02         0.000000e+00
# 25%        42.127734     -71.548384         6.091488e+05         5.099480e+03
# 50%        42.317359     -71.154657         1.167824e+06         9.241530e+03
# 75%        42.456725     -71.024271         1.468306e+06         1.820228e+04
# max        42.901078     -69.921561         3.203008e+06         1.595563e+06
#
#                  Age  Allergy to bee venom  Allergy to dairy product  \
# count  147451.000000          13722.000000              13722.000000
# mean       55.374531              0.172497                  0.037750
# std        18.818082              0.377825                  0.190597
# min         0.000000              0.000000                  0.000000
# 25%        40.000000              0.000000                  0.000000
# 50%        59.000000              0.000000                  0.000000
# 75%        71.000000              0.000000                  0.000000
# max        84.000000              1.000000                  1.000000
#
#        Allergy to eggs  Allergy to fish  Allergy to grass pollen  ...  \
# count     13722.000000     13722.000000             13722.000000  ...
# mean          0.049701         0.167541                 0.257105  ...
# std           0.217335         0.373472                 0.437054  ...
# min           0.000000         0.000000                 0.000000  ...
# 25%           0.000000         0.000000                 0.000000  ...
# 50%           0.000000         0.000000                 0.000000  ...
# 75%           0.000000         0.000000                 1.000000  ...
# max           1.000000         1.000000                 1.000000  ...
#
#        PLACE_BIRTH_PL  PLACE_BIRTH_PR  PLACE_BIRTH_PT  PLACE_BIRTH_RU  \
# count   147451.000000   147451.000000   147451.000000   147451.000000
# mean         0.000922        0.010342        0.000692        0.002258
# std          0.030356        0.101171        0.026292        0.047469
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        0.000000        0.000000        0.000000
# 50%          0.000000        0.000000        0.000000        0.000000
# 75%          0.000000        0.000000        0.000000        0.000000
# max          1.000000        1.000000        1.000000        1.000000
#
#        PLACE_BIRTH_SA  PLACE_BIRTH_SV  PLACE_BIRTH_US  PLACE_BIRTH_VE  \
# count   147451.000000   147451.000000   147451.000000   147451.000000
# mean         0.000068        0.001892        0.907766        0.002096
# std          0.008235        0.043458        0.289357        0.045730
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        0.000000        1.000000        0.000000
# 50%          0.000000        0.000000        1.000000        0.000000
# 75%          0.000000        0.000000        1.000000        0.000000
# max          1.000000        1.000000        1.000000        1.000000
#
#        PLACE_BIRTH_VN  PLACE_BIRTH_nan
# count   147451.000000         147451.0
# mean         0.004313              0.0
# std          0.065534              0.0
# min          0.000000              0.0
# 25%          0.000000              0.0
# 50%          0.000000              0.0
# 75%          0.000000              0.0
# max          1.000000              0.0
#
# [8 rows x 999 columns]

# %%
from sklearn.model_selection import KFold
nfold = 5
target = 'is_train'
skf = KFold(n_splits=nfold, shuffle=True, random_state=2019)

oof = np.zeros(len(train_test))
#predictions = np.zeros(len(test))

# %%
i = 1

for train_index, valid_index in skf.split(train_test, train_test.is_train.values):
    print("\nfold {}".format(i))
    
    #Train data
    t=train_test.iloc[train_index]
        
    xg_train = lgb.Dataset(t[predictors].values,
                           label=t[target].values,
                           feature_name=predictors,
                           free_raw_data = False
                           )
    
    xg_valid = lgb.Dataset(train_test.iloc[valid_index][predictors].values,
                           label=train_test.iloc[valid_index][target].values,
                           feature_name=predictors,
                           free_raw_data = False
                           )   

    num_rounds = 50000
    clf = lgb.train(param, xg_train, num_rounds, valid_sets = [xg_train, xg_valid], 
                    verbose_eval=2000, early_stopping_rounds = 100)  #1000
    oof[valid_index] = clf.predict(train_test.iloc[valid_index][predictors].values, num_iteration=clf.best_iteration) 
    #save models
    clf.save_model('lgb_classifier_fold{}.txt'.format(i), num_iteration=clf.best_iteration) 
    #to read model model = lgb.Booster(model_file='lgb_classifier.txt')
    #predictions += clf.predict(test, num_iteration=clf.best_iteration) / nfold
    i = i + 1
# Out:
# fold 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [37]	training's auc: 0.638344	valid_1's auc: 0.505684
#
# fold 2
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [82]	training's auc: 0.705582	valid_1's auc: 0.501737
#
# fold 3
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2]	training's auc: 0.521921	valid_1's auc: 0.506258
#
# fold 4
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [5]	training's auc: 0.537115	valid_1's auc: 0.507343
#
# fold 5
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [5]	training's auc: 0.54599	valid_1's auc: 0.507181

# %%
print("\n\nCV AUC: {:<0.5f}".format(metrics.roc_auc_score(train_test.is_train.values.astype(bool), oof)))
print("\n\nCV log loss: {:<0.5f}".format(metrics.log_loss(train_test.is_train.values.astype(bool), oof)))
print("\n\nCV Gini: {:<0.5f}".format(2 * metrics.roc_auc_score(train_test.is_train.values.astype(bool), oof) -1))
# Out:
# CV AUC: 0.50305
#
#
# CV log loss: 0.50083
#
#
# CV Gini: 0.00610

# %%
print(metrics.classification_report(train_test.is_train.values.astype(bool), oof >0.5))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00     29492
#         True       0.80      1.00      0.89    117959
#
#     accuracy                           0.80    147451
#    macro avg       0.40      0.50      0.44    147451
# weighted avg       0.64      0.80      0.71    147451

# %%
print(metrics.classification_report(train_test.is_train.values.astype(bool), oof >0.1))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00     29492
#         True       0.80      1.00      0.89    117959
#
#     accuracy                           0.80    147451
#    macro avg       0.40      0.50      0.44    147451
# weighted avg       0.64      0.80      0.71    147451
# /home/maria/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(metrics.classification_report(train_test.is_train.values.astype(bool), oof >0.05))
# Out:
# /home/maria/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00     29492
#         True       0.80      1.00      0.89    117959
#
#     accuracy                           0.80    147451
#    macro avg       0.40      0.50      0.44    147451
# weighted avg       0.64      0.80      0.71    147451

# %% [markdown]
# # Explainability

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# %%
fpr_rf, tpr_rf, _ = roc_curve(train_test.is_train.values.astype(bool), oof)

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_rf, tpr_rf, label='RF')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %%
from sklearn.metrics import average_precision_score
average_precision = average_precision_score(train_test.is_train.values.astype(bool), oof)

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.80

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.pipeline import make_pipeline

# %%
#https://eli5.readthedocs.io/en/latest/tutorials/xgboost-titanic.html#simple-xgboost-classifier

# %%
import seaborn as sns

# %%
imp_df = pd.DataFrame()
imp_df['feature'] = predictors
imp_df['gain']  = clf.feature_importance(importance_type='gain')
imp_df['split'] = clf.feature_importance(importance_type='split')

# %%
def plot_importances(importances_):
    mean_gain = importances_[['gain', 'feature']].groupby('feature').mean()
    importances_['mean_gain'] = importances_['feature'].map(mean_gain['gain'])
    plt.figure(figsize=(18, 44))
    data_imp = importances_.sort_values('mean_gain', ascending=False)
    sns.barplot(x='gain', y='feature', data=data_imp[:300])
    plt.tight_layout()
    plt.savefig('importances.png')
    plt.show()

# %%
plot_importances(imp_df)
