# %% [markdown]
# # Import Libraries for analysis

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import OneHotEncoder
from sklearn import metrics

#Light GBM
import lightgbm as lgb


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

PATH = '/media/maria/2TB Monster driv/PrecisionFDA/'
PATH_COVID = '/media/maria/2TB Monster driv/PrecisionFDA/LightGBM/COVID/'

# %% [markdown]
# # Import Databases

# %%
train = pd.read_csv(PATH + 'Descriptive/train.csv')
test = pd.read_csv(PATH + 'Descriptive/test.csv')

# %%
nocovid  = pd.read_csv(PATH_COVID + 'no_covid_predicted.csv')

# %%
train = train.loc[train['COVID_Status']==1]

# %%
#Display all database
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %%
display_all(train.describe())
# Out:
#        DRIVERS  PASSPORT           LAT           LON  HEALTHCARE_EXPENSES  \
# count  73697.0   73697.0  73697.000000  73697.000000         7.369700e+04
# mean       1.0       1.0     42.276641    -71.355158         9.958533e+05
# std        0.0       0.0      0.280952      0.594560         5.257319e+05
# min        1.0       1.0     41.241591    -73.490615         4.391440e+03
# 25%        1.0       1.0     42.126691    -71.537896         6.186478e+05
# 50%        1.0       1.0     42.316542    -71.153067         1.078231e+06
# 75%        1.0       1.0     42.455546    -71.022418         1.440909e+06
# max        1.0       1.0     42.900027    -69.921561         3.203008e+06
#
#        HEALTHCARE_COVERAGE           Age  Allergy to bee venom  \
# count         7.369700e+04  73697.000000           7545.000000
# mean          2.272775e+04     53.953974              0.190192
# std           5.957766e+04     18.640218              0.392479
# min           0.000000e+00     21.000000              0.000000
# 25%           5.048600e+03     38.000000              0.000000
# 50%           8.902250e+03     55.000000              0.000000
# 75%           1.581682e+04     70.000000              0.000000
# max           1.557373e+06     84.000000              1.000000
#
#        Allergy to dairy product  Allergy to eggs  Allergy to fish  \
# count               7545.000000      7545.000000      7545.000000
# mean                   0.038436         0.046918         0.183035
# std                    0.192259         0.211478         0.386721
# min                    0.000000         0.000000         0.000000
# 25%                    0.000000         0.000000         0.000000
# 50%                    0.000000         0.000000         0.000000
# 75%                    0.000000         0.000000         0.000000
# max                    1.000000         1.000000         1.000000
#
#        Allergy to grass pollen  Allergy to mould  Allergy to nut  \
# count              7545.000000       7545.000000     7545.000000
# mean                  0.278330          0.381975        0.180517
# std                   0.448206          0.485903        0.384643
# min                   0.000000          0.000000        0.000000
# 25%                   0.000000          0.000000        0.000000
# 50%                   0.000000          0.000000        0.000000
# 75%                   1.000000          1.000000        0.000000
# max                   1.000000          1.000000        1.000000
#
#        Allergy to peanuts  Allergy to soya  Allergy to tree pollen  \
# count         7545.000000      7545.000000             7545.000000
# mean             0.196024         0.017097                0.271040
# std              0.397013         0.129643                0.444526
# min              0.000000         0.000000                0.000000
# 25%              0.000000         0.000000                0.000000
# 50%              0.000000         0.000000                0.000000
# 75%              0.000000         0.000000                1.000000
# max              1.000000         1.000000                1.000000
#
#        Allergy to wheat  Dander (animal) allergy  House dust mite allergy  \
# count       7545.000000              7545.000000              7545.000000
# mean           0.043738                 0.353612                 0.268257
# std            0.204524                 0.478122                 0.443082
# min            0.000000                 0.000000                 0.000000
# 25%            0.000000                 0.000000                 0.000000
# 50%            0.000000                 0.000000                 0.000000
# 75%            0.000000                 1.000000                 1.000000
# max            1.000000                 1.000000                 1.000000
#
#        Latex allergy  Shellfish allergy  Agreeing on diabetes care plan  \
# count    7545.000000        7545.000000                    67162.000000
# mean        0.071703           0.319682                        0.000030
# std         0.258013           0.466384                        0.005457
# min         0.000000           0.000000                        0.000000
# 25%         0.000000           0.000000                        0.000000
# 50%         0.000000           0.000000                        0.000000
# 75%         0.000000           1.000000                        0.000000
# max         1.000000           1.000000                        1.000000
#
#        Allergic disorder monitoring  Anti-suicide psychotherapy  \
# count                  67162.000000                67162.000000
# mean                       0.001102                    0.002159
# std                        0.033176                    0.046415
# min                        0.000000                    0.000000
# 25%                        0.000000                    0.000000
# 50%                        0.000000                    0.000000
# 75%                        0.000000                    0.000000
# max                        1.000000                    1.000000
#
#        Asthma self management     Burn care  Cancer care plan     Care Plan  \
# count            67162.000000  67162.000000      67162.000000  67162.000000
# mean                 0.045145      0.002993          0.141226      0.319600
# std                  0.207623      0.054897          0.352422      0.466325
# min                  0.000000      0.000000          0.000000      0.000000
# 25%                  0.000000      0.000000          0.000000      0.000000
# 50%                  0.000000      0.000000          0.000000      0.000000
# 75%                  0.000000      0.000000          0.000000      1.000000
# max                  1.000000      2.000000          2.000000      1.000000
#
#        Care plan (record artifact)  \
# count                 67162.000000
# mean                      0.050296
# std                       0.218557
# min                       0.000000
# 25%                       0.000000
# 50%                       0.000000
# 75%                       0.000000
# max                       1.000000
#
#        Chronic obstructive pulmonary disease clinical management plan  \
# count                                       67162.000000
# mean                                            0.029109
# std                                             0.168113
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Demential management  Diabetes self management plan  \
# count          67162.000000                   67162.000000
# mean               0.038519                       0.592180
# std                0.192447                       0.491433
# min                0.000000                       0.000000
# 25%                0.000000                       0.000000
# 50%                0.000000                       1.000000
# 75%                0.000000                       1.000000
# max                1.000000                       1.000000
#
#        Dialysis care plan (record artifact)  Fracture care  \
# count                          67162.000000   67162.000000
# mean                               0.011093       0.018120
# std                                0.104736       0.145967
# min                                0.000000       0.000000
# 25%                                0.000000       0.000000
# 50%                                0.000000       0.000000
# 75%                                0.000000       0.000000
# max                                1.000000       5.000000
#
#        Head injury rehabilitation  Heart failure self management plan  \
# count                67162.000000                        67162.000000
# mean                     0.006090                            0.009038
# std                      0.078939                            0.094638
# min                      0.000000                            0.000000
# 25%                      0.000000                            0.000000
# 50%                      0.000000                            0.000000
# 75%                      0.000000                            0.000000
# max                      3.000000                            1.000000
#
#        Hyperlipidemia clinical management plan  \
# count                             67162.000000
# mean                                  0.178628
# std                                   0.383043
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000
#
#        Inpatient care plan (record artifact)  \
# count                           67162.000000
# mean                                0.000759
# std                                 0.029123
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 2.000000
#
#        Lifestyle education regarding hypertension  \
# count                                67162.000000
# mean                                     0.403785
# std                                      0.490659
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      1.000000
# max                                      1.000000
#
#        Major depressive disorder clinical management plan  \
# count                                       67162.000000
# mean                                            0.077514
# std                                             0.267407
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Major surgery care management  Mental health care plan  \
# count                   67162.000000             67162.000000
# mean                        0.001578                 0.168786
# std                         0.039696                 0.374566
# min                         0.000000                 0.000000
# 25%                         0.000000                 0.000000
# 50%                         0.000000                 0.000000
# 75%                         0.000000                 0.000000
# max                         1.000000                 1.000000
#
#        Mental health care plan (record artifact)  \
# count                               67162.000000
# mean                                    0.003023
# std                                     0.054895
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Minor surgery care management (procedure)  Musculoskeletal care  \
# count                               67162.000000          67162.000000
# mean                                    0.002174              0.180042
# std                                     0.046574              0.472765
# min                                     0.000000              0.000000
# 25%                                     0.000000              0.000000
# 50%                                     0.000000              0.000000
# 75%                                     0.000000              0.000000
# max                                     1.000000              6.000000
#
#        Overactivity/inattention behavior management  \
# count                                       67162.0
# mean                                            0.0
# std                                             0.0
# min                                             0.0
# 25%                                             0.0
# 50%                                             0.0
# 75%                                             0.0
# max                                             0.0
#
#        Physical therapy procedure  Postoperative care  Psychiatry care plan  \
# count                67162.000000        67162.000000          67162.000000
# mean                     0.014726            0.000313              0.206009
# std                      0.130994            0.017680              0.404440
# min                      0.000000            0.000000              0.000000
# 25%                      0.000000            0.000000              0.000000
# 50%                      0.000000            0.000000              0.000000
# 75%                      0.000000            0.000000              0.000000
# max                      5.000000            1.000000              1.000000
#
#        Respiratory therapy  Routine antenatal care  \
# count         67162.000000            67162.000000
# mean              0.121661                0.145231
# std               0.578869                0.748165
# min               0.000000                0.000000
# 25%               0.000000                0.000000
# 50%               0.000000                0.000000
# 75%               0.000000                0.000000
# max              10.000000               11.000000
#
#        Self-care interventions (procedure)  Skin condition care  \
# count                         67162.000000         67162.000000
# mean                              0.169262             0.007281
# std                               0.374986             0.085018
# min                               0.000000             0.000000
# 25%                               0.000000             0.000000
# 50%                               0.000000             0.000000
# 75%                               0.000000             0.000000
# max                               1.000000             1.000000
#
#        Spinal cord injury rehabilitation  Terminal care  \
# count                       67162.000000   67162.000000
# mean                            0.000134       0.021724
# std                             0.011575       0.145781
# min                             0.000000       0.000000
# 25%                             0.000000       0.000000
# 50%                             0.000000       0.000000
# 75%                             0.000000       0.000000
# max                             1.000000       1.000000
#
#        Urinary tract infection care    Wound care  \
# count                  67162.000000  67162.000000
# mean                       0.003395      0.011748
# std                        0.059181      0.109531
# min                        0.000000      0.000000
# 25%                        0.000000      0.000000
# 50%                        0.000000      0.000000
# 75%                        0.000000      0.000000
# max                        2.000000      3.000000
#
#        Acute bronchitis (disorder)_x  Alzheimer's disease (disorder)_x  \
# count                   65012.000000                      65012.000000
# mean                        0.125684                          0.035409
# std                         0.587933                          0.184812
# min                         0.000000                          0.000000
# 25%                         0.000000                          0.000000
# 50%                         0.000000                          0.000000
# 75%                         0.000000                          0.000000
# max                        10.000000                          1.000000
#
#            Asthma_x  At risk for suicide (finding)_x  Atopic dermatitis_x  \
# count  65012.000000                     65012.000000         65012.000000
# mean       0.002400                         0.000015             0.006445
# std        0.048927                         0.003922             0.080022
# min        0.000000                         0.000000             0.000000
# 25%        0.000000                         0.000000             0.000000
# 50%        0.000000                         0.000000             0.000000
# 75%        0.000000                         0.000000             0.000000
# max        1.000000                         1.000000             1.000000
#
#        Attempted suicide - cut/stab_x  Attempted suicide - suffocation_x  \
# count                    65012.000000                       65012.000000
# mean                         0.000431                           0.000323
# std                          0.020749                           0.017970
# min                          0.000000                           0.000000
# 25%                          0.000000                           0.000000
# 50%                          0.000000                           0.000000
# 75%                          0.000000                           0.000000
# max                          1.000000                           1.000000
#
#        Bullet wound_x  Child attention deficit disorder_x  Childhood asthma_x  \
# count    65012.000000                             65012.0        65012.000000
# mean         0.000154                                 0.0            0.044238
# std          0.012401                                 0.0            0.205625
# min          0.000000                                 0.0            0.000000
# 25%          0.000000                                 0.0            0.000000
# 50%          0.000000                                 0.0            0.000000
# 75%          0.000000                                 0.0            0.000000
# max          1.000000                                 0.0            1.000000
#
#        Chronic congestive heart failure (disorder)_x  \
# count                                   65012.000000
# mean                                        0.009337
# std                                         0.096175
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        Chronic obstructive bronchitis (disorder)_x  Closed fracture of hip_x  \
# count                                 65012.000000              65012.000000
# mean                                      0.013874                  0.001415
# std                                       0.116970                  0.037592
# min                                       0.000000                  0.000000
# 25%                                       0.000000                  0.000000
# 50%                                       0.000000                  0.000000
# 75%                                       0.000000                  0.000000
# max                                       1.000000                  1.000000
#
#        Concussion injury of brain_x  Concussion with loss of consciousness_x  \
# count                  65012.000000                             65012.000000
# mean                       0.000323                                 0.001261
# std                        0.017970                                 0.035493
# min                        0.000000                                 0.000000
# 25%                        0.000000                                 0.000000
# 50%                        0.000000                                 0.000000
# 75%                        0.000000                                 0.000000
# max                        1.000000                                 1.000000
#
#        Concussion with no loss of consciousness_x  Contact dermatitis_x  \
# count                                65012.000000          65012.000000
# mean                                     0.004707              0.001077
# std                                      0.069781              0.032796
# min                                      0.000000              0.000000
# 25%                                      0.000000              0.000000
# 50%                                      0.000000              0.000000
# 75%                                      0.000000              0.000000
# max                                      3.000000              1.000000
#
#        Cystic Fibrosis_x    Cystitis_x    Diabetes_x  \
# count       65012.000000  65012.000000  65012.000000
# mean            0.000031      0.001307      0.154464
# std             0.005546      0.036135      0.361396
# min             0.000000      0.000000      0.000000
# 25%             0.000000      0.000000      0.000000
# 50%             0.000000      0.000000      0.000000
# 75%             0.000000      0.000000      0.000000
# max             1.000000      1.000000      1.000000
#
#        Diabetes from Cystic Fibrosis_x  Drug overdose_x  \
# count                     65012.000000     65012.000000
# mean                          0.000031         0.059589
# std                           0.005546         0.236726
# min                           0.000000         0.000000
# 25%                           0.000000         0.000000
# 50%                           0.000000         0.000000
# 75%                           0.000000         0.000000
# max                           1.000000         1.000000
#
#        Escherichia coli urinary tract infection_x  Facial laceration_x  \
# count                                65012.000000         65012.000000
# mean                                     0.002169             0.002461
# std                                      0.047177             0.049858
# min                                      0.000000             0.000000
# 25%                                      0.000000             0.000000
# 50%                                      0.000000             0.000000
# 75%                                      0.000000             0.000000
# max                                      2.000000             2.000000
#
#        Familial Alzheimer's disease of early onset (disorder)_x  \
# count                                       65012.000000
# mean                                            0.004384
# std                                             0.066066
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        First degree burn_x  Fracture of ankle_x  Fracture of clavicle_x  \
# count         65012.000000         65012.000000            65012.000000
# mean              0.001738             0.003707                0.003830
# std               0.042023             0.062519                0.063246
# min               0.000000             0.000000                0.000000
# 25%               0.000000             0.000000                0.000000
# 50%               0.000000             0.000000                0.000000
# 75%               0.000000             0.000000                0.000000
# max               2.000000             3.000000                2.000000
#
#        Fracture of forearm_x  Fracture of rib_x  \
# count           65012.000000       65012.000000
# mean                0.004845           0.001569
# std                 0.070320           0.039579
# min                 0.000000           0.000000
# 25%                 0.000000           0.000000
# 50%                 0.000000           0.000000
# 75%                 0.000000           0.000000
# max                 2.000000           1.000000
#
#        Fracture of vertebral column without spinal cord injury_x  \
# count                                       65012.000000
# mean                                            0.000138
# std                                             0.011765
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Fracture subluxation of wrist_x        Gout_x  Hyperlipidemia_x  \
# count                     65012.000000  65012.000000      65012.000000
# mean                          0.003353      0.009860          0.184535
# std                           0.059644      0.098806          0.387923
# min                           0.000000      0.000000          0.000000
# 25%                           0.000000      0.000000          0.000000
# 50%                           0.000000      0.000000          0.000000
# 75%                           0.000000      0.000000          0.000000
# max                           2.000000      1.000000          1.000000
#
#        Hypertension_x  Injury of anterior cruciate ligament_x  \
# count    65012.000000                            65012.000000
# mean         0.417138                                0.000523
# std          0.493090                                0.022863
# min          0.000000                                0.000000
# 25%          0.000000                                0.000000
# 50%          0.000000                                0.000000
# 75%          1.000000                                0.000000
# max          1.000000                                1.000000
#
#        Injury of medial collateral ligament of knee_x  \
# count                                    65012.000000
# mean                                         0.000661
# std                                          0.025710
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          1.000000
#
#        Injury of tendon of the rotator cuff of shoulder_x  \
# count                                       65012.000000
# mean                                            0.001415
# std                                             0.037999
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             2.000000
#
#        Laceration of foot_x  Laceration of forearm_x  Laceration of hand_x  \
# count          65012.000000             65012.000000          65012.000000
# mean               0.002200                 0.002307              0.002723
# std                0.046849                 0.047979              0.052986
# min                0.000000                 0.000000              0.000000
# 25%                0.000000                 0.000000              0.000000
# 50%                0.000000                 0.000000              0.000000
# 75%                0.000000                 0.000000              0.000000
# max                1.000000                 1.000000              2.000000
#
#        Laceration of thigh_x  Localized  primary osteoarthritis of the hand_x  \
# count           65012.000000                                     65012.000000
# mean                0.002292                                         0.029948
# std                 0.048140                                         0.170446
# min                 0.000000                                         0.000000
# 25%                 0.000000                                         0.000000
# 50%                 0.000000                                         0.000000
# 75%                 0.000000                                         0.000000
# max                 2.000000                                         1.000000
#
#        Lupus erythematosus_x  Major depression  single episode_x  \
# count           65012.000000                        65012.000000
# mean                0.000108                            0.174368
# std                 0.010376                            0.379428
# min                 0.000000                            0.000000
# 25%                 0.000000                            0.000000
# 50%                 0.000000                            0.000000
# 75%                 0.000000                            0.000000
# max                 1.000000                            1.000000
#
#        Major depression disorder_x  Male Infertility_x  \
# count                 65012.000000             65012.0
# mean                      0.200102                 0.0
# std                       0.507195                 0.0
# min                       0.000000                 0.0
# 25%                       0.000000                 0.0
# 50%                       0.000000                 0.0
# 75%                       0.000000                 0.0
# max                       2.000000                 0.0
#
#        Malignant tumor of colon_x  Neoplasm of prostate_x  \
# count                65012.000000            65012.000000
# mean                     0.003384                0.138944
# std                      0.067847                0.345890
# min                      0.000000                0.000000
# 25%                      0.000000                0.000000
# 50%                      0.000000                0.000000
# 75%                      0.000000                0.000000
# max                      2.000000                1.000000
#
#        Non-small cell carcinoma of lung  TNM stage 1 (disorder)_x  \
# count                                       65012.000000
# mean                                            0.019012
# std                                             0.136568
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Normal pregnancy_x  Osteoarthritis of hip_x  Osteoarthritis of knee_x  \
# count        65012.000000             65012.000000              65012.000000
# mean             0.150034                 0.026872                  0.073679
# std              0.759962                 0.161710                  0.261249
# min              0.000000                 0.000000                  0.000000
# 25%              0.000000                 0.000000                  0.000000
# 50%              0.000000                 0.000000                  0.000000
# 75%              0.000000                 0.000000                  0.000000
# max             11.000000                 1.000000                  1.000000
#
#        Overlapping malignant neoplasm of colon_x  \
# count                               65012.000000
# mean                                    0.003692
# std                                     0.072860
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     2.000000
#
#        Posttraumatic stress disorder_x  Prediabetes_x  \
# count                     65012.000000   65012.000000
# mean                          0.095921       0.457300
# std                           0.304904       0.498177
# min                           0.000000       0.000000
# 25%                           0.000000       0.000000
# 50%                           0.000000       0.000000
# 75%                           0.000000       1.000000
# max                           2.000000       1.000000
#
#        Primary fibromyalgia syndrome_x  Primary malignant neoplasm of colon_x  \
# count                     65012.000000                           65012.000000
# mean                          0.004307                               0.001215
# std                           0.065486                               0.037394
# min                           0.000000                               0.000000
# 25%                           0.000000                               0.000000
# 50%                           0.000000                               0.000000
# 75%                           0.000000                               0.000000
# max                           1.000000                               2.000000
#
#        Primary small cell malignant neoplasm of lung  TNM stage 1 (disorder)_x  \
# count                                       65012.000000
# mean                                            0.003430
# std                                             0.058467
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Pulmonary emphysema (disorder)_x  Pyelonephritis_x  \
# count                      65012.000000      65012.000000
# mean                           0.016197          0.000031
# std                            0.126234          0.005546
# min                            0.000000          0.000000
# 25%                            0.000000          0.000000
# 50%                            0.000000          0.000000
# 75%                            0.000000          0.000000
# max                            1.000000          1.000000
#
#        Rheumatoid arthritis_x  Rupture of patellar tendon_x  \
# count            65012.000000                  65012.000000
# mean                 0.003123                      0.000677
# std                  0.055792                      0.026007
# min                  0.000000                      0.000000
# 25%                  0.000000                      0.000000
# 50%                  0.000000                      0.000000
# 75%                  0.000000                      0.000000
# max                  1.000000                      1.000000
#
#        Second degree burn_x  Secondary malignant neoplasm of colon_x  \
# count          65012.000000                             65012.000000
# mean               0.001169                                 0.000185
# std                0.034171                                 0.013585
# min                0.000000                                 0.000000
# 25%                0.000000                                 0.000000
# 50%                0.000000                                 0.000000
# 75%                0.000000                                 0.000000
# max                1.000000                                 1.000000
#
#        Smokes tobacco daily_x  Sprain of ankle_x  Sprain of wrist_x  \
# count            65012.000000       65012.000000       65012.000000
# mean                 0.155417           0.007968           0.003522
# std                  0.362305           0.091801           0.061288
# min                  0.000000           0.000000           0.000000
# 25%                  0.000000           0.000000           0.000000
# 50%                  0.000000           0.000000           0.000000
# 75%                  0.000000           0.000000           0.000000
# max                  1.000000           3.000000           3.000000
#
#        Suicidal deliberate poisoning_x  Tear of meniscus of knee_x  \
# count                     65012.000000                65012.000000
# mean                          0.001477                    0.000446
# std                           0.038399                    0.021116
# min                           0.000000                    0.000000
# 25%                           0.000000                    0.000000
# 50%                           0.000000                    0.000000
# 75%                           0.000000                    0.000000
# max                           1.000000                    1.000000
#
#        Third degree burn_x  Whiplash injury to neck_x  Acute Cholecystitis_x  \
# count         65012.000000               65012.000000           70810.000000
# mean              0.000185                   0.038101               0.000268
# std               0.013585                   0.213978               0.016379
# min               0.000000                   0.000000               0.000000
# 25%               0.000000                   0.000000               0.000000
# 50%               0.000000                   0.000000               0.000000
# 75%               0.000000                   0.000000               0.000000
# max               1.000000                   5.000000               1.000000
#
#        Acute allergic reaction  Acute bacterial sinusitis (disorder)_x  \
# count             70810.000000                            70810.000000
# mean                  0.000212                                0.005282
# std                   0.014553                                0.073644
# min                   0.000000                                0.000000
# 25%                   0.000000                                0.000000
# 50%                   0.000000                                0.000000
# 75%                   0.000000                                0.000000
# max                   1.000000                                2.000000
#
#        Acute bronchitis (disorder)_y  Acute viral pharyngitis (disorder)_x  \
# count                   70810.000000                          70810.000000
# mean                        0.036421                              0.044584
# std                         0.221724                              0.252437
# min                         0.000000                              0.000000
# 25%                         0.000000                              0.000000
# 50%                         0.000000                              0.000000
# 75%                         0.000000                              0.000000
# max                        10.000000                             11.000000
#
#          Alcoholism  Alzheimer's disease (disorder)_y  Anemia (disorder)_x  \
# count  70810.000000                       70810.00000         70810.000000
# mean       0.115351                           0.03251             0.445784
# std        0.319447                           0.17735             0.497055
# min        0.000000                           0.00000             0.000000
# 25%        0.000000                           0.00000             0.000000
# 50%        0.000000                           0.00000             0.000000
# 75%        0.000000                           0.00000             1.000000
# max        1.000000                           1.00000             1.000000
#
#        Antepartum eclampsia  Appendicitis_x      Asthma_y  \
# count          70810.000000    70810.000000  70810.000000
# mean               0.001582        0.059045      0.002203
# std                0.039739        0.235711      0.046886
# min                0.000000        0.000000      0.000000
# 25%                0.000000        0.000000      0.000000
# 50%                0.000000        0.000000      0.000000
# 75%                0.000000        0.000000      0.000000
# max                1.000000        1.000000      1.000000
#
#        At risk for suicide (finding)_y  Atopic dermatitis_y  \
# count                     70810.000000         70810.000000
# mean                          0.001751             0.005917
# std                           0.041811             0.076696
# min                           0.000000             0.000000
# 25%                           0.000000             0.000000
# 50%                           0.000000             0.000000
# 75%                           0.000000             0.000000
# max                           1.000000             1.000000
#
#        Atrial Fibrillation_x  Bleeding from anus_x  Blighted ovum_x  \
# count           70810.000000          70810.000000     70810.000000
# mean                0.048920              0.002471         0.001285
# std                 0.215702              0.049652         0.035826
# min                 0.000000              0.000000         0.000000
# 25%                 0.000000              0.000000         0.000000
# 50%                 0.000000              0.000000         0.000000
# 75%                 0.000000              0.000000         0.000000
# max                 1.000000              1.000000         1.000000
#
#        Blindness due to type 2 diabetes mellitus (disorder)  \
# count                                       70810.000000
# mean                                            0.000113
# std                                             0.010629
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Body mass index 30+ - obesity (finding)  \
# count                             70810.000000
# mean                                  0.483562
# std                                   0.499733
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   1.000000
# max                                   1.000000
#
#        Body mass index 40+ - severely obese (finding)  \
# count                                    70810.000000
# mean                                         0.011820
# std                                          0.108078
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          1.000000
#
#        Brain damage - traumatic  Bullet wound_y  \
# count              70810.000000    70810.000000
# mean                   0.007570        0.000127
# std                    0.086674        0.011273
# min                    0.000000        0.000000
# 25%                    0.000000        0.000000
# 50%                    0.000000        0.000000
# 75%                    0.000000        0.000000
# max                    1.000000        1.000000
#
#        Burn injury(morphologic abnormality)_x  \
# count                                 70810.0
# mean                                      0.0
# std                                       0.0
# min                                       0.0
# 25%                                       0.0
# 50%                                       0.0
# 75%                                       0.0
# max                                       0.0
#
#        Carcinoma in situ of prostate (disorder)  Cardiac Arrest_x  \
# count                              70810.000000      70810.000000
# mean                                   0.125646          0.042649
# std                                    0.331452          0.202067
# min                                    0.000000          0.000000
# 25%                                    0.000000          0.000000
# 50%                                    0.000000          0.000000
# 75%                                    0.000000          0.000000
# max                                    1.000000          1.000000
#
#        Child attention deficit disorder_y  Childhood asthma_y  Cholelithiasis  \
# count                             70810.0        70810.000000    70810.000000
# mean                                  0.0            0.000071        0.000268
# std                                   0.0            0.008403        0.016379
# min                                   0.0            0.000000        0.000000
# 25%                                   0.0            0.000000        0.000000
# 50%                                   0.0            0.000000        0.000000
# 75%                                   0.0            0.000000        0.000000
# max                                   0.0            1.000000        1.000000
#
#        Chronic congestive heart failure (disorder)_y  \
# count                                   70810.000000
# mean                                        0.008939
# std                                         0.094126
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        Chronic intractable migraine without aura_x  \
# count                                 70810.000000
# mean                                      0.058367
# std                                       0.234439
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                       1.000000
#
#        Chronic kidney disease stage 1 (disorder)  \
# count                               70810.000000
# mean                                    0.150812
# std                                     0.357868
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Chronic kidney disease stage 2 (disorder)  \
# count                               70810.000000
# mean                                    0.023514
# std                                     0.151529
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Chronic kidney disease stage 3 (disorder)  \
# count                               70810.000000
# mean                                    0.000890
# std                                     0.029815
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# ...
# std                                     0.015332
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     3.000000
#
#        Acute bronchitis (disorder)_y.1  Acute viral pharyngitis (disorder)  \
# count                     13759.000000                        13759.000000
# mean                          0.116796                            0.040047
# std                           0.323444                            0.196446
# min                           0.000000                            0.000000
# 25%                           0.000000                            0.000000
# 50%                           0.000000                            0.000000
# 75%                           0.000000                            0.000000
# max                           2.000000                            2.000000
#
#        Appendicitis  Atrial Fibrillation_y  Bullet wound_y.1  \
# count  13759.000000           13759.000000      13759.000000
# mean       0.002544               0.974417          0.000363
# std        0.050374               3.737371          0.019060
# min        0.000000               0.000000          0.000000
# 25%        0.000000               0.000000          0.000000
# 50%        0.000000               0.000000          0.000000
# 75%        0.000000               0.000000          0.000000
# max        1.000000              40.000000          1.000000
#
#        Cardiac Arrest_y.1  Child attention deficit disorder_y.1  \
# count        13759.000000                               13759.0
# mean             0.005669                                   0.0
# std              0.130293                                   0.0
# min              0.000000                                   0.0
# 25%              0.000000                                   0.0
# 50%              0.000000                                   0.0
# 75%              0.000000                                   0.0
# max              3.000000                                   0.0
#
#        Chronic obstructive bronchitis (disorder)_y.1  \
# count                                   13759.000000
# mean                                        0.092449
# std                                         0.596935
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                        16.000000
#
#        Closed fracture of hip_y.1  Facial laceration  Fracture of ankle_y.1  \
# count                13759.000000       13759.000000           13759.000000
# mean                     0.006905           0.011701               0.018461
# std                      0.101000           0.122102               0.181518
# min                      0.000000           0.000000               0.000000
# 25%                      0.000000           0.000000               0.000000
# 50%                      0.000000           0.000000               0.000000
# 75%                      0.000000           0.000000               0.000000
# max                      2.000000           2.000000               2.000000
#
#        Fracture of clavicle_y.1  Fracture of forearm_y.1  Fracture of rib_y.1  \
# count              13759.000000             13759.000000         13759.000000
# mean                   0.021222                 0.022385             0.008504
# std                    0.196236                 0.190084             0.127029
# min                    0.000000                 0.000000             0.000000
# 25%                    0.000000                 0.000000             0.000000
# 50%                    0.000000                 0.000000             0.000000
# 75%                    0.000000                 0.000000             0.000000
# max                    2.000000                 2.000000             2.000000
#
#        Fracture subluxation of wrist_y.1  \
# count                       13759.000000
# mean                            0.016934
# std                             0.175356
# min                             0.000000
# 25%                             0.000000
# 50%                             0.000000
# 75%                             0.000000
# max                             2.000000
#
#        Injury of anterior cruciate ligament_y.1  \
# count                              13759.000000
# mean                                   0.001454
# std                                    0.038100
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.000000
# max                                    1.000000
#
#        Injury of medial collateral ligament of knee_y.1  \
# count                                      13759.000000
# mean                                           0.002180
# std                                            0.046645
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# max                                            1.000000
#
#        Injury of tendon of the rotator cuff of shoulder_y.1  \
# count                                       13759.000000
# mean                                            0.000727
# std                                             0.026950
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Laceration of foot  Laceration of forearm  Laceration of hand  \
# count        13759.000000           13759.000000        13759.000000
# mean             0.011265               0.011919            0.013664
# std              0.122143               0.123560            0.134106
# min              0.000000               0.000000            0.000000
# 25%              0.000000               0.000000            0.000000
# 50%              0.000000               0.000000            0.000000
# 75%              0.000000               0.000000            0.000000
# max              2.000000               2.000000            2.000000
#
#        Laceration of thigh  Major depression  single episode_y.1  \
# count         13759.000000                               13759.0
# mean              0.012574                                   0.0
# std               0.132852                                   0.0
# min               0.000000                                   0.0
# 25%               0.000000                                   0.0
# 50%               0.000000                                   0.0
# 75%               0.000000                                   0.0
# max               2.000000                                   0.0
#
#        Malignant neoplasm of breast (disorder)  Malignant tumor of colon_y.1  \
# count                             13759.000000                  13759.000000
# mean                                  0.282651                      0.018751
# std                                   1.666036                      0.301323
# min                                   0.000000                      0.000000
# 25%                                   0.000000                      0.000000
# 50%                                   0.000000                      0.000000
# 75%                                   0.000000                      0.000000
# max                                  41.000000                      7.000000
#
#        Myocardial Infarction_y.1  Neoplasm of prostate_y.1  \
# count               13759.000000              13759.000000
# mean                    0.002398                  0.024275
# std                     0.084794                  0.153907
# min                     0.000000                  0.000000
# 25%                     0.000000                  0.000000
# 50%                     0.000000                  0.000000
# 75%                     0.000000                  0.000000
# max                     3.000000                  1.000000
#
#        Non-small cell carcinoma of lung  TNM stage 1 (disorder)_y.1  \
# count                                       13759.000000
# mean                                            0.629697
# std                                             2.057190
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            10.000000
#
#        Normal pregnancy_y.1  Overlapping malignant neoplasm of colon_y.1  \
# count          13759.000000                                 13759.000000
# mean               4.198125                                     0.011047
# std                9.563766                                     0.206086
# min                0.000000                                     0.000000
# 25%                0.000000                                     0.000000
# 50%                0.000000                                     0.000000
# 75%                0.000000                                     0.000000
# max               45.000000                                     7.000000
#
#        Polyp of colon  Posttraumatic stress disorder_y.1  \
# count    13759.000000                       13759.000000
# mean         0.073116                           0.026165
# std          0.390173                           0.314705
# min          0.000000                           0.000000
# 25%          0.000000                           0.000000
# 50%          0.000000                           0.000000
# 75%          0.000000                           0.000000
# max          3.000000                           5.000000
#
#        Primary malignant neoplasm of colon_y.1  \
# count                             13759.000000
# mean                                  0.000363
# std                                   0.019060
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000
#
#        Primary small cell malignant neoplasm of lung  TNM stage 1 (disorder)_y.1  \
# count                                       13759.000000
# mean                                            0.144415
# std                                             1.164668
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            13.000000
#
#        Pulmonary emphysema (disorder)_y.1  Recurrent rectal polyp_y  \
# count                        13759.000000              13759.000000
# mean                             0.116651                  0.007704
# std                              0.701367                  0.087437
# min                              0.000000                  0.000000
# 25%                              0.000000                  0.000000
# 50%                              0.000000                  0.000000
# 75%                              0.000000                  0.000000
# max                             18.000000                  1.000000
#
#        Rupture of patellar tendon_y.1  \
# count                    13759.000000
# mean                         0.002035
# std                          0.045067
# min                          0.000000
# 25%                          0.000000
# 50%                          0.000000
# 75%                          0.000000
# max                          1.000000
#
#        Secondary malignant neoplasm of colon_y.1  \
# count                               13759.000000
# mean                                    0.001163
# std                                     0.075287
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     6.000000
#
#        Streptococcal sore throat (disorder)    Stroke_y.1  \
# count                          13759.000000  13759.000000
# mean                               0.027328      0.033869
# std                                0.163931      0.259185
# min                                0.000000      0.000000
# 25%                                0.000000      0.000000
# 50%                                0.000000      0.000000
# 75%                                0.000000      0.000000
# max                                2.000000      4.000000
#
#        Suicidal deliberate poisoning_y.1  Suspected lung cancer (situation)  \
# count                       13759.000000                       13759.000000
# mean                            0.000654                           0.060033
# std                             0.044295                           0.416481
# min                             0.000000                           0.000000
# 25%                             0.000000                           0.000000
# 50%                             0.000000                           0.000000
# 75%                             0.000000                           0.000000
# max                             3.000000                           3.000000
#
#        Third degree burn_y.1  Tubal pregnancy  COVID_Status         Death  \
# count           13759.000000     13759.000000       73697.0  73697.000000
# mean                0.001599         0.000145           1.0      0.075553
# std                 0.055229         0.012056           0.0      0.264283
# min                 0.000000         0.000000           1.0      0.000000
# 25%                 0.000000         0.000000           1.0      0.000000
# 50%                 0.000000         0.000000           1.0      0.000000
# 75%                 0.000000         0.000000           1.0      0.000000
# max                 2.000000         1.000000           1.0      1.000000
#
#        Days_hospitalized  Hospitalized    Ventilator     Days_ICU  \
# count       20393.000000  73697.000000  73697.000000  4981.000000
# mean           12.623505      0.276714      0.057126     6.218474
# std             4.945529      0.447377      0.232084     2.757986
# min             1.000000      0.000000      0.000000     1.000000
# 25%             8.259722      0.000000      0.000000     4.063194
# 50%            13.297917      0.000000      0.000000     6.072917
# 75%            16.331250      1.000000      0.000000     8.265278
# max            21.498611      1.000000      1.000000    11.700000
#
#                 ICU
# count  73697.000000
# mean       0.067588
# std        0.251039
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
#save oof
oof_df = train[["Id", "ICU"]]

# %% [markdown]
# # Hyperparameters

# %%
seed = 42
#Using the parameters from ICU mortality 

param = {'num_leaves': 15, 
        'boosting_type': 'gbdt',
        'learning_rate': 0.01,
        'colsample_bytree': 0.6189140385454879,
        'subsample': 0.7098267979279573,
        'reg_alpha': 5, 
        'reg_lambda': 1, 
        'scale_pos_weight': 1,
        'save_binary': True,
        'seed': seed,
        'feature_fraction_seed': seed,
        'bagging_seed': seed,
        'drop_seed': seed,
        'data_random_seed': seed,
        'objective': 'binary',  
        'verbose': 1,
        'metric': {'binary_logloss', 'auc'},
        'is_unbalance': False, 
        'boost_from_average': True,
        'extra_trees': True
    }

# %%
train.drop(columns=['Death', 'COVID_Status', 'Ventilator', 'Hospitalized', 
                    'Id', 'Days_hospitalized', 'Days_ICU'], inplace=True)

# %%
test.drop(columns=['Id'], inplace=True)

# %%
predictors_int = list(train.columns)

# %%
cat_names = ['DRIVERS' , 'PASSPORT', 'MARITAL', 'RACE', 'ETHNICITY',
             'GENDER', 'COUNTY',  'PLACE_BIRTH']

# %%
predictors_int.remove('DRIVERS')
predictors_int.remove('PASSPORT')
predictors_int.remove('MARITAL')
predictors_int.remove('RACE')
predictors_int.remove('ETHNICITY')
predictors_int.remove('GENDER')
predictors_int.remove('COUNTY')
predictors_int.remove('PLACE_BIRTH')

# %% [markdown]
# # Creation of Dummies and missing values handling

# %%
train['is_train'] = 1
test['is_train'] = 0
train_test= pd.concat([train,test], axis = 0, sort=False)

# %%
#one-hot encoding of categorical variables
train_test = pd.get_dummies(train_test, columns = cat_names, dummy_na=True)

# %%
train = train_test.loc[train_test.is_train==1]

# %%
train = train.drop(columns=['is_train'])

# %%
test = train_test.loc[train_test.is_train==0]
#test.drop(columns=['is_train'], inplace=True)

# %%
test = test.drop(columns=['is_train'])

# %%
predictors = list(train.columns)
predictors.remove('ICU')

# %%
#predictors.remove('Oxygen saturation in Arterial blood')
#predictors.remove('Body temperature')
#predictors.remove('Respiratory rate')
#predictors.remove('Heart rate')

# %% [markdown]
# # Training Loop

# %%
from sklearn.model_selection import KFold
nfold = 5
target = 'ICU'
skf = KFold(n_splits=nfold, shuffle=True, random_state=2019)

oof = np.zeros(len(train))
predictions = np.zeros(len(test))

# %%
i = 1

for train_index, valid_index in skf.split(train, train.ICU.values):
    print("\nfold {}".format(i))
    
    #Train data
    t=train.iloc[train_index]
        
    xg_train = lgb.Dataset(t[predictors].values,
                           label=t[target].values,
                           feature_name=predictors,
                           free_raw_data = False
                           )
    
    xg_valid = lgb.Dataset(train.iloc[valid_index][predictors].values,
                           label=train.iloc[valid_index][target].values,
                           feature_name=predictors,
                           free_raw_data = False
                           )   

    num_rounds = 50000
    clf = lgb.train(param, xg_train, num_rounds, valid_sets = [xg_train, xg_valid], 
                    verbose_eval=2000, early_stopping_rounds = 100)  #1000
    oof[valid_index] = clf.predict(train.iloc[valid_index][predictors].values, num_iteration=clf.best_iteration) 
    #save models
    clf.save_model('lgb_classifier_fold{}.txt'.format(i), num_iteration=clf.best_iteration) 
    #to read model model = lgb.Booster(model_file='lgb_classifier.txt')
    predictions += clf.predict(test[predictors], num_iteration=clf.best_iteration) / nfold
    i = i + 1
# Out:
# fold 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [595]	training's auc: 0.800245	training's binary_logloss: 0.203771	valid_1's auc: 0.760834	valid_1's binary_logloss: 0.214657
#
# fold 2
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [690]	training's auc: 0.798625	training's binary_logloss: 0.204472	valid_1's auc: 0.785524	valid_1's binary_logloss: 0.206764
#
# fold 3
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1105]	training's auc: 0.813875	training's binary_logloss: 0.198267	valid_1's auc: 0.777901	valid_1's binary_logloss: 0.209784
#
# fold 4
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1147]	training's auc: 0.815142	training's binary_logloss: 0.197613	valid_1's auc: 0.78322	valid_1's binary_logloss: 0.210882
#
# fold 5
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [963]	training's auc: 0.815983	training's binary_logloss: 0.197054	valid_1's auc: 0.753442	valid_1's binary_logloss: 0.221235

# %%
print("\n\nCV AUC: {:<0.5f}".format(metrics.roc_auc_score(train.ICU.values.astype(bool), oof)))
print("\n\nCV log loss: {:<0.5f}".format(metrics.log_loss(train.ICU.values.astype(bool), oof)))
print("\n\nCV Gini: {:<0.5f}".format(2 * metrics.roc_auc_score(train.ICU.values.astype(bool), oof) -1))
# Out:
# CV AUC: 0.77167
#
#
# CV log loss: 0.21266
#
#
# CV Gini: 0.54334

# %%
maximum = 0
for i in range(1000):
    f1 = metrics.f1_score(train.ICU.values.astype(bool), oof >i*.001)
    if f1 > maximum:
        maximum=f1
        threshold =  i*0.001

print(f'Maximum f1 value: {maximum}' , f'Probability cutoff: {threshold}' )
# Out:
# Maximum f1 value: 0.30444856348470806 Probability cutoff: 0.146

# %%
print(metrics.classification_report(train.ICU.values.astype(bool), oof >threshold))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.95      0.91      0.93     68716
#         True       0.25      0.40      0.30      4981
#
#     accuracy                           0.88     73697
#    macro avg       0.60      0.65      0.62     73697
# weighted avg       0.91      0.88      0.89     73697

# %% [markdown]
# # Export results

# %%
sub_df = pd.read_csv(PATH + 'Descriptive/test.csv')
sub_df["ICU"] = predictions

# %%
sub_df["ICU_flag"] = (predictions > threshold) * 1

# %%
nocovid["COVID_flag"] = 0

# %%
#No COVID has ICU == 0

sub_df = sub_df.merge(nocovid, how='left', left_on ='Id', right_on ='Id')
sub_df['COVID_flag'] = sub_df['COVID_flag'].fillna(1)

# %%
sub_df["ICU"] = sub_df["ICU"] * sub_df['COVID_flag'] * sub_df["ICU_flag"]

# %%
sub_df[['Id', 'ICU']].to_csv("lightgbm_icu_status.csv", index=False)

# %%
np.mean(sub_df['ICU'])
# Out:
# 0.017334421292402886

# %%
oof_df["prediction_LGBM"] = oof
oof_df[:10]
# Out:
#                                       Id  ICU  prediction_LGBM
# 3   afa2680f-7f73-46d9-b0cd-2cf3db49724b  0.0         0.022916
# 4   26e5d262-6cdc-4274-a5cd-d7fd439e35f9  0.0         0.027787
# 5   90031c21-e8a4-416e-b60b-23e871ee62dc  0.0         0.027538
# 6   0ac2e031-ab88-41f9-ac5d-d7d588952222  0.0         0.019412
# 7   45138fb4-dc79-4aec-ba78-7a012d3edca7  0.0         0.030240
# 8   fba0823a-d6fc-402f-a6c3-9394f54b1870  0.0         0.015465
# 9   93ef4d47-2a1e-4af1-b792-96a6077b75e0  0.0         0.015047
# 10  ff524e84-ef48-4c59-8e16-ff28514271a1  0.0         0.013924
# 11  5c6dd9dd-effb-4ba6-a059-a60579b86ee1  0.0         0.042869
# 12  c58ae02e-235e-4db2-a9c3-6926e9c0c5fa  1.0         0.072161

# %%
oof_df.to_csv("Ooflightgbm.csv", index=False)

# %% [markdown]
# # Explainability

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# %%
fpr_rf, tpr_rf, _ = roc_curve(train.ICU.values.astype(bool), oof)

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_rf, tpr_rf, label='LGBM')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %%
from sklearn.metrics import average_precision_score
average_precision = average_precision_score(train.ICU.values.astype(bool), oof)

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.26

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.pipeline import make_pipeline

# %%
#https://eli5.readthedocs.io/en/latest/tutorials/xgboost-titanic.html#simple-xgboost-classifier

# %%
import seaborn as sns

# %%
imp_df = pd.DataFrame()
imp_df['feature'] = predictors
imp_df['gain']  = clf.feature_importance(importance_type='gain')
imp_df['split'] = clf.feature_importance(importance_type='split')

# %%
def plot_importances(importances_):
    mean_gain = importances_[['gain', 'feature']].groupby('feature').mean()
    importances_['mean_gain'] = importances_['feature'].map(mean_gain['gain'])
    plt.figure(figsize=(18, 44))
    data_imp = importances_.sort_values('mean_gain', ascending=False)
    sns.barplot(x='gain', y='feature', data=data_imp[:300])
    plt.tight_layout()
    plt.savefig('importances.png')
    plt.show()

# %%
plot_importances(imp_df)

# %%
import shap

explainer   =  shap.TreeExplainer(clf)
shap_values = explainer.shap_values(t[predictors])
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray

# %%
shap.summary_plot(shap_values[1], t[predictors])

# %%
shap.decision_plot(explainer.expected_value[1], shap_values[1], predictors, ignore_warnings=True,
                  legend_labels=None)

# %%
shap.dependence_plot('DALY', shap_values[1], t[predictors])

# %%
shap.dependence_plot('QOLS', shap_values[1], t[predictors], interaction_index='DALY')

# %%
shap.dependence_plot('Heart rate', shap_values[1], t[predictors])

# %%
shap.dependence_plot('DALY', shap_values[1], t[predictors])
